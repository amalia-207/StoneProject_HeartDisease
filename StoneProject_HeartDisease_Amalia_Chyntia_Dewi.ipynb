# %%
from google.colab import files
import pandas as pd
import io

uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded['heart.csv']))
df.head()
# Out:
#      <input type="file" id="files-6842510f-d976-413a-a709-4cae86e557d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6842510f-d976-413a-a709-4cae86e557d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install replicate
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
from google.colab import userdata
import os

# ambil api_token dari secret
api_token = userdata.get("api_token")

# lempar api_token ke env. var.
os.environ["REPLICATE_API_TOKEN"] = api_token

# %%
from langchain_community.llms import Replicate

# Get the llm
llm = Replicate(model="ibm-granite/granite-3.3-8b-instruct")

# %%
import replicate

prompt = """
You are a data scientist. Analyze the heart disease dataset (303 rows, 14 columns).
Summarize the key insights in bullet points, including:
- Age and gender distribution
- Proportion of patients with and without heart disease
- Risk factors that correlate with heart disease (blood pressure, cholesterol, chest pain, maximum heart rate, exercise-induced angina)
- Any unusual patterns or anomalies
- Final conclusion: which features are most strongly associated with heart disease
"""

output = replicate.run(
    "meta/meta-llama-3-8b-instruct",
    input={"prompt": prompt}
)

print("".join(output))
# Out:
# After analyzing the heart disease dataset, I've identified the following key insights:
#
# **Age and Gender Distribution:**
#
# * The dataset contains 303 patients, with an average age of 53.4 years (range: 29-75 years).
# * The majority of patients are male (72.5%), with 27.5% being female.
# * The age distribution is skewed towards older patients, with 60% of patients above the age of 50.
#
# **Proportion of Patients with and without Heart Disease:**
#
# * 156 patients (51.5%) have heart disease, while 147 patients (48.5%) do not.
# * The dataset is moderately imbalanced, with a slightly higher proportion of patients without heart disease.
#
# **Risk Factors Correlated with Heart Disease:**
#
# * Blood pressure: Patients with high blood pressure (> 140/90 mmHg) are more likely to have heart disease (OR: 2.35, p-value: 0.001).
# * Cholesterol: Patients with high cholesterol (> 240 mg/dL) are more likely to have heart disease (OR: 1.83, p-value: 0.02).
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("heart.csv")

# 1. Age distribution
plt.figure(figsize=(8,6))
sns.histplot(df['age'], bins=20, kde=True, color="skyblue")
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# 2. Gender vs Heart Disease
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="sex", hue="target", palette="Set2")
plt.title('Gender vs Heart Disease')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.show()

# 3. Chest Pain Types
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="cp", hue="target", palette="Set1")
plt.title('Chest Pain Types by Heart Disease')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# 4. Cholesterol vs Heart Disease
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x="target", y="chol", palette="Pastel1")
plt.title('Cholesterol Levels by Heart Disease')
plt.xlabel('Heart Disease (0 = No, 1 = Yes)')
plt.ylabel('Cholesterol')
plt.show()

# 5. Max Heart Rate vs Age
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="age", y="thalach", hue="target", palette="coolwarm")
plt.title('Max Heart Rate vs Age')
plt.xlabel('Age')
plt.ylabel('Max Heart Rate (thalach)')
plt.show()

# 6. Correlation Heatmap
plt.figure(figsize=(12,8))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /tmp/ipython-input-2276068482.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="target", y="chol", palette="Pastel1")

# %%
import replicate

prompt = """
You are a data analyst. Summarize the conclusions from the visualizations of the heart disease dataset in clear bullet points.
Focus on:
- Age distribution
- Gender vs Heart Disease
- Chest pain types by heart disease status
- Blood pressure and cholesterol patterns
- Maximum heart rate and exercise-induced angina

Format the output ONLY as bullet points, without long paragraphs.
"""

output = replicate.run(
    "meta/meta-llama-3-8b-instruct",
    input={"prompt": prompt}
)

print("".join(output))
# Out:
# Here are the conclusions from the visualizations of the heart disease dataset:
#
# • The age distribution of the dataset is skewed towards older individuals, with a median age of 60 years.
# • Males are more likely to develop heart disease, with 76% of heart disease cases being male.
# • Patients with heart disease are more likely to experience chest pain type 3 (Tress), with 62% of heart disease cases having type 3 chest pain.
# • Patients with heart disease tend to have higher blood pressure and cholesterol levels, with 85% of heart disease cases having high blood pressure and 90% having high cholesterol.
# • Maximum heart rate is lower in patients with heart disease, with a median maximum heart rate of 120 bpm compared to 130 bpm in non-heart disease patients.
# • Exercise-induced angina is more common in patients with heart disease, with 55% of heart disease cases experiencing exercise-induced angina compared to 20% of non-heart disease cases.
